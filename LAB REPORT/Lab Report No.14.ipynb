# %% [markdown]
# # Lab Report Details
#
# | **Field**        | **Details**         |
# |-------------------|---------------------|
# | **Name**         | MUHAMMAD Ubaid         |
# | **Req No**       | 23jzele 0556         |
# | **Lab Report No**| 14                 |

# %% [markdown]
# ## Problem Statement
# The goal of this statistical analysis is to help us understand the relationship between house features and how these variables are used to predict house price.

# %% [markdown]
# ## Objective
# Predict the house price
# Using two different models in terms of minimizing the difference between predicted and actual rating

# %% [markdown]
# ## Step 1: Exploratory Data Analysis (EDA)
# First, Let’s import the data and have a look to see what kind of data we are dealing with:

# %% [markdown]
# ## Import required libraries

# %% [markdown]
# ## numpy
#  NumPy, is the short form of "Numerical Python,"  this is a fundamental Python library for numerical computing. It provides support for large, multi-dimensional arrays and matrices, along with a wide range of high-level mathematical functions to operate on these arrays. NumPy is wonderful in scientific and data analysis tasks because it offers efficient and optimized implementations of numerical operations, making it significantly faster than traditional Python lists. It's widely used in scientific research, data analysis, machine learning, and various other domains. Compared to other libraries, NumPy's primary competitors include MATLAB for numerical computing, but NumPy is open-source and integrates seamlessly into the Python ecosystem, making it more accessible and cost-effective. Additionally, NumPy forms the foundation for many other scientific libraries in Python, like SciPy, scikit-learn, and pandas, enhancing its overall utility and importance in the Python data science stack.

# %%
import numpy as np

# %% [markdown]
# ##  Matplotlib
# Matplotlib is a popular Python library for creating static, animated, or interactive visualizations in various formats such as line plots, bar charts, scatter plots, and more. It provides fine-grained control over the appearance and customization of plots, making it suitable for both simple and complex data visualization tasks. Matplotlib is highly extensible and compatible with various GUI toolkits, making it a versatile choice for generating publication-quality graphs and charts. It is often used in data analysis, scientific research, and data visualization projects.
# With the help of matplot lib library we will plot the data

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Pandas
# Pandas is a powerful Python library for data manipulation and analysis. It provides easy-to-use data structures like DataFrames and Series, which allow users to efficiently handle and analyze structured data. Pandas is widely used in data science and data analysis tasks, offering functionality for data cleaning, filtering, aggregation, and visualization. It seamlessly integrates with other popular libraries like NumPy and Matplotlib, making it an essential tool for working with tabular data in Python.

# %%
import pandas as pd

# %% [markdown]
# ## Seaborn
# Seaborn is a Python data visualization library based on Matplotlib, providing a high-level interface for creating attractive and informative statistical graphics. It simplifies the process of creating complex visualizations by offering easy-to-use functions. Seaborn enhances Matplotlib's aesthetics and provides built-in themes and color palettes. It supports various plot types, including scatter plots, bar plots, and heatmaps, with concise syntax. Seaborn seamlessly integrates with Pandas DataFrames, making it convenient for working with structured data. Overall, Seaborn is a powerful tool for exploratory data analysis and presentation-ready visualizations in a concise and elegant manner.

# %%
import seaborn as sns

# %% [markdown]
# ## Sklearn
# Scikit-learn, often referred to as sklearn, is a popular Python library for machine learning and data science. It provides a wide range of tools and algorithms for tasks such as classification, regression, clustering, dimensionality reduction, and more. Scikit-learn is known for its user-friendly API and extensive documentation, making it a preferred choice for both beginners and experienced data scientists. It also offers support for model selection, hyperparameter tuning, and model evaluation, making it an essential tool for building and deploying machine learning models in Python.
#
# modules in sklearn library
# Scikit-learn (sklearn) is a comprehensive library for machine learning in Python, and it consists of several modules that cover various aspects of machine learning tasks. Here is a list of some of the key modules in scikit-learn:
#
# sklearn.datasets: This module provides various datasets for practice and experimentation, including sample datasets like Iris and digits.
#
# sklearn.preprocessing: It contains functions for data preprocessing, such as scaling, encoding categorical variables, and imputing missing values.
#
# sklearn.model_selection: This module includes tools for model selection, including functions for splitting datasets into training and testing sets, cross-validation, and hyperparameter tuning.
#
# sklearn.feature_selection: It offers methods for feature selection to choose the most relevant features for model training.
#
# sklearn.linear_model: This module includes linear models for tasks like regression and classification. It contains algorithms like Linear Regression, Logistic Regression, and Ridge Regression.
#
# sklearn.tree: It provides Decision Tree-based models for both classification and regression tasks.
#
# sklearn.cluster: It contains clustering algorithms such as K-Means and hierarchical clustering.
#
# sklearn.svm: This module includes support vector machine algorithms for classification and regression.
#
# sklearn.neighbors: It offers algorithms like K-Nearest Neighbors (KNN) for both classification and regression problems.
#
# sklearn.metrics: It provides various metrics for evaluating model performance, including accuracy, precision, recall, and more.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ## Tensorflow
# TensorFlow is an open-source machine learning framework developed by Google. It facilitates the creation and training of machine learning models, particularly deep neural networks. TensorFlow employs a dataflow graph to represent computations, allowing for efficient parallel processing and optimization. Its versatility spans various applications, from image and speech recognition to natural language processing.

# %%
# Creating a Neural Network Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Read the file
# With the help of pandas library we will read the file at the jupyter notebook and read the features and target of the data. And with the help of this library there will be differnt type of data we can read such as( csv,excel) and after this we can perform changing in the data like (cleaning, scaling, ploting)

# %%
#import Data
Data = pd.read_csv(r'C:\Users\Computer Zone\Downloads\archive\kc_house_data.csv')
Data.head(5).T
# Out:
#                              0                1                2  \
# id                  7129300520       6414100192       5631500400
# date           20141013T000000  20141209T000000  20150225T000000
# price                 221900.0         538000.0         180000.0
# bedrooms                     3                3                2
# bathrooms                  1.0             2.25              1.0
# sqft_living               1180             2570              770
# sqft_lot                  5650             7242            10000
# floors                     1.0              2.0              1.0
# waterfront                   0                0                0
# view                         0                0                0
# condition                    3                3                3
# grade                        7                7                6
# sqft_above                1180             2170              770
# ...

# %%
#get some information about our Data-Set
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ## Describtion of Data

# %%
Data.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %% [markdown]
# ## visualizing house prices

# %%
#visualizing house prices
fig = plt.figure(figsize=(10,7))
fig.add_subplot(2,1,1)
sns.distplot(Data['price'])
fig.add_subplot(2,1,2)
sns.boxplot(Data['price'])
plt.tight_layout()
# Out:
# C:\Users\Computer Zone\AppData\Local\Temp\ipykernel_9980\3928838082.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Data['price'])

# %%
fig = plt.figure(figsize=(16, 5))

# Subplot 1
ax1 = fig.add_subplot(2, 2, 1)
sns.scatterplot(x='sqft_above', y='price', data=Data, ax=ax1)

# Subplot 2
ax2 = fig.add_subplot(2, 2, 2)
sns.scatterplot(x='sqft_lot', y='price', data=Data, ax=ax2)

# Subplot 3
ax3 = fig.add_subplot(2, 2, 3)
sns.scatterplot(x='sqft_living', y='price', data=Data, ax=ax3)

# Subplot 4
ax4 = fig.add_subplot(2, 2, 4)
sns.scatterplot(x='sqft_basement', y='price', data=Data, ax=ax4)

plt.show()

# %%
#visualizing bedrooms,bathrooms,floors,grade
fig = plt.figure(figsize=(15,7))
fig.add_subplot(2,2,1)
sns.histplot(Data['bedrooms'])
fig.add_subplot(2,2,2)
sns.histplot(Data['floors'])
fig.add_subplot(2,2,3)
sns.histplot(Data['bathrooms'])
fig.add_subplot(2,2,4)
sns.histplot(Data['grade'])
plt.tight_layout()

# %%
#let's break date to years, months
Data['date'] = pd.to_datetime(Data['date'])
Data['month'] = Data['date'].apply(lambda date:date.month)
Data['year'] = Data['date'].apply(lambda date:date.year)

# %%
#data visualization house price vs months and years
fig = plt.figure(figsize=(16,5))
fig.add_subplot(1,2,1)
Data.groupby('month').mean()['price'].plot()
fig.add_subplot(1,2,2)
Data.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
# check if there are any Null values
Data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# month            0
# year             0
# dtype: int64

# %% [markdown]
# ## drop some unnecessary columns

# %%
Data = Data.drop('date',axis=1)
Data = Data.drop('id',axis=1)
Data = Data.drop('zipcode',axis=1)

# %% [markdown]
# ## Step 2: Dataset Preparation (Splitting and Scaling)
# Data is divided into the Train set and Test set. We use the Train set to make the algorithm learn the data’s behavior and then check the accuracy of our model on the Test set.
#
# Features (X): The columns that are inserted into our model will be used to make predictions.
# Prediction (y): Target variable that will be predicted by the features

# %%
Data.dropna(inplace=True)

# %%
X = Data.drop('price',axis =1).values
y = Data['price'].values

# %%
#splitting Train and Test 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
#standardization scaler - fit&transform on train, fit only on test

s_scaler = StandardScaler()
X_train = s_scaler.fit_transform(X_train)
X_test = s_scaler.transform(X_test)

# %% [markdown]
# ## Step 3: Model Selection and Evaluation
# 💡Model 1: Multiple Linear Regressions
# Multiple Linear Regression is an extension of Simple Linear Regression (read more here) and assume that there is a linear relationship between a dependent variable Y and independent variables X
#
# Let’s wrap the training process in our Regression model:

# %%
# Multiple Liner Regression

regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#evaluate the model (intercept and slope)
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 540068.0331492655
# [-32174.26458621  28314.47160234  80960.8365489    6428.24177905
#    3413.70406639  49942.35152741  36835.82051685  21903.68879982
#  116003.40529456  76073.5117404   25375.83805414 -72994.52529983
#    7676.57141888  78057.84710672 -17254.48220907  18909.70160034
#  -10301.37920458   4182.48580611  17081.43533197]

# %%
#predicting the test set result
y_pred = regressor.predict(X_test)

# %%
#put results as a DataFrame
coeff_df = pd.DataFrame(regressor.coef_, Data.drop('price',axis =1).columns, columns=['Coefficient']) 
coeff_df
# Out:
#                  Coefficient
# bedrooms       -32174.264586
# bathrooms       28314.471602
# sqft_living     80960.836549
# sqft_lot         6428.241779
# floors           3413.704066
# waterfront      49942.351527
# view            36835.820517
# condition       21903.688800
# grade          116003.405295
# sqft_above      76073.511740
# sqft_basement   25375.838054
# yr_built       -72994.525300
# yr_renovated     7676.571419
# lat             78057.847107
# long           -17254.482209
# sqft_living15   18909.701600
# sqft_lot15     -10301.379205
# month            4182.485806
# year            17081.435332

# %%
# visualizing residuals
fig = plt.figure(figsize=(10,5))
residuals = (y_test- y_pred)
sns.distplot(residuals)
# Out:
# C:\Users\Computer Zone\AppData\Local\Temp\ipykernel_9980\2877839159.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals)
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Let’s compare actual output and predicted value to measure how far our predictions are from the real house prices.

# %%
#compare actual output values with predicted values
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(10)
df1
# Out:
#      Actual      Predicted
# 0  349950.0  530667.784120
# 1  450000.0  667025.076946
# 2  635000.0  553195.043391
# 3  355500.0  346657.166101
# 4  246950.0   61378.186019
# 5  406550.0  481162.809294
# 6  350000.0  312819.788488
# 7  226500.0  273833.027682
# 8  265000.0  280571.649291
# 9  656000.0  532966.844438

# %%
# evaluate the performance of the algorithm (MAE - MSE - RMSE)

print('MAE:', metrics.mean_absolute_error(y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(y_test,y_pred))
# Out:
# MAE: 125933.74319633955
# MSE: 40601153229.61856
# RMSE: 201497.27846702686
# VarScore: 0.7039747986273114

# %% [markdown]
# ## 💡Model 2: Keras Regressions
# Let’s create a baseline neural network model for the regression problem. Starting with all of the needed functions and objects.

# %% [markdown]
# ## Since we have 19 features, let’s insert 19 neurons as a start, 4 hidden layers and 1 output layer due to predict house Price.
#
# Also, ADAM optimization algorithm is used for optimizing loss function (Mean squared error)

# %%
# having 19 neuron is based on the number of available features
model = Sequential()
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))
model.compile(optimizer='Adam',loss='mes')

# %% [markdown]
# ## Then, we train the model for 400 epochs, and each time record the training and validation accuracy in the history object. To keep track of how well the model is performing for each epoch, the model will run in both train and test data along with calculating the loss function.

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
model.summary()
# Out:
# Epoch 1/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 421279465472.0000 - mae: 541117.5625 - val_loss: 428803391488.0000 - val_mae: 540069.9375
# Epoch 2/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 417240743936.0000 - mae: 538508.6875 - val_loss: 423926595584.0000 - val_mae: 536729.0625
# Epoch 3/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 420538449920.0000 - mae: 534078.6875 - val_loss: 376054677504.0000 - val_mae: 502697.2188
# Epoch 4/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 345844645888.0000 - mae: 479807.4688 - val_loss: 217304727552.0000 - val_mae: 365357.5938
# Epoch 5/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 176860725248.0000 - mae: 319179.5625 - val_loss: 85478301696.0000 - val_mae: 213017.2188
# Epoch 6/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 80930291712.0000 - mae: 205376.5781 - val_loss: 68739129344.0000 - val_mae: 191283.5156
# Epoch 7/400
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot(figsize=(12,8))
# Out:
# <Axes: >

# %% [markdown]
# ## Evaluation on Test Data

# %%
y_pred = model.predict(X_test)

print('MAE:', metrics.mean_absolute_error(y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(y_test,y_pred))
# Out:
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# MAE: 101560.09589233142
# MSE: 26628542035.554333
# RMSE: 163182.54206732512
# VarScore: 0.8059719830806962

# %%
# Visualizing Our predictions
fig = plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)
# Perfect predictions
plt.plot(y_test,y_test,'r')

# %%
# visualizing residuals
fig = plt.figure(figsize=(10,5))
residuals = (y_test- y_pred)
sns.distplot(residuals)
# Out:
# C:\Users\Computer Zone\AppData\Local\Temp\ipykernel_9980\2877839159.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals)
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Keras Regression vs Multiple Linear Regression!
# We made it!💪
# we have predicted the house price using two different ML model algorithms.
#
# The score of our Multiple Linear Regression is around 69%, so this model had room for improvement. Then we got an accuracy of ~78% with Keras Regression model.
# Also, notice that RMSE (loss function) is lower for Keras Regression model which shows that our prediction is closer to actual rating price.
